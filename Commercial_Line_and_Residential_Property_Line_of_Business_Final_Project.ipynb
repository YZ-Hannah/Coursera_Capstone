# %% [markdown]
# # Commercial Line- Analysis on Business Interruption due to COVID-19

# %% [markdown]
# ## Create Toronto Borough Map

# %% [markdown]
# ### Scrape Toronto Geographic Information from Wikipedia Page

# %%
# import the library we use to open URLs
import urllib.request
import pandas as pd
import numpy as np

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)

# %%
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup=BeautifulSoup(page,"lxml")

# %%
table=soup.find("table", class_='wikitable sortable')
A=[]
B=[]
C=[]
for row in table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %% [markdown]
# ### Data Cleaning

# %%
df=pd.DataFrame(A,columns=['PostalCode'])
df['Borough']=B
df['Neighborhood']=C
# Removing extra \n at the end of each word
df.replace('\n','',regex=True, inplace=True)
#Remove rows with "Not assigned" for Borough
df=df[df.Borough!='Not assigned']
df.replace("/",",",regex=True,inplace=True)

# %%
df_group=df.groupby('PostalCode')['Neighborhood'].apply(','.join).reset_index()
df_group
df_final=pd.merge(df_group,df[['PostalCode','Borough']])
column_name=['PostalCode','Borough','Neighborhood']
df=df_final.reindex(columns=column_name)
df.head(103)
# Out:
#     PostalCode      Borough                                       Neighborhood
# 0          M1B  Scarborough                                    Malvern , Rouge
# 1          M1C  Scarborough           Rouge Hill , Port Union , Highland Creek
# 2          M1E  Scarborough                Guildwood , Morningside , West Hill
# 3          M1G  Scarborough                                             Woburn
# 4          M1H  Scarborough                                          Cedarbrae
# ..         ...          ...                                                ...
# 98         M9N         York                                             Weston
# 99         M9P    Etobicoke                                          Westmount
# 100        M9R    Etobicoke  Kingsview Village , St. Phillips , Martin Grov...
# 101        M9V    Etobicoke  South Steeles , Silverstone , Humbergate , Jam...
# 102        M9W    Etobicoke                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# ### Add Latitude and Longitude into the Dataset

# %%
df_geo=pd.read_csv("http://cocl.us/Geospatial_data")
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_tot=pd.merge(df,df_geo,left_on='PostalCode', right_on='Postal Code')
del df_tot['Postal Code']
df_tot.head()
# Out:
#   PostalCode      Borough                              Neighborhood  \
# 0        M1B  Scarborough                           Malvern , Rouge
# 1        M1C  Scarborough  Rouge Hill , Port Union , Highland Creek
# 2        M1E  Scarborough       Guildwood , Morningside , West Hill
# 3        M1G  Scarborough                                    Woburn
# 4        M1H  Scarborough                                 Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# ### Visualize Toronto Borough Map

# %%
# !pip install folium
import folium

! pip install geopy
import geopy.geocoders
from geopy.geocoders import Nominatim

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs
import requests
# Out:
# Requirement already satisfied: folium in c:\users\e78202\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\e78202\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: numpy in c:\users\e78202\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\e78202\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: requests in c:\users\e78202\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\e78202\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\users\e78202\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.14.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\e78202\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\e78202\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\e78202\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\e78202\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: geopy in c:\users\e78202\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\e78202\anaconda3\lib\site-packages (from geopy) (1.50)

# %%
df_group=df_tot.groupby('Borough', as_index=False).mean()
df_group
# Out:
#             Borough   Latitude  Longitude
# 0   Central Toronto  43.701980 -79.398954
# 1  Downtown Toronto  43.654597 -79.383972
# 2      East Toronto  43.669436 -79.324654
# 3         East York  43.700303 -79.335851
# 4         Etobicoke  43.660043 -79.542074
# 5       Mississauga  43.636966 -79.615819
# 6        North York  43.750727 -79.429338
# 7       Scarborough  43.766229 -79.249085
# 8      West Toronto  43.652653 -79.449290
# 9              York  43.690797 -79.472633

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values

map_toronto1 = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough in zip(df_group['Latitude'], df_group['Longitude'], df_group['Borough']):
    label = '{}'.format(borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto1)  
    
map_toronto1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Collect Venues Information using Foursquare API

# %%
CLIENT_ID = '13EQVOFZOMNIADMU20H0UWKSKA0AAD5PS3IZ5EOGSQHQMZZ2' # your Foursquare ID
CLIENT_SECRET = '5DKAAAAX1R0LOJKDCZDKYWZAFEF1UBHGRCBWRCTLIWCY5KQG' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 13EQVOFZOMNIADMU20H0UWKSKA0AAD5PS3IZ5EOGSQHQMZZ2
# CLIENT_SECRET:5DKAAAAX1R0LOJKDCZDKYWZAFEF1UBHGRCBWRCTLIWCY5KQG

# %% [markdown]
# ### Explore Borough

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    LIMIT = 100 # limit of number of venues returned by Foursquare API
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_group['Borough'],
                                   latitudes=df_group['Latitude'],
                                   longitudes=df_group['Longitude']
                                  )
toronto_venues
# Out:
# Central Toronto
# Downtown Toronto
# East Toronto
# East York
# Etobicoke
# Mississauga
# North York
# Scarborough
# West Toronto
# York
#              Borough  Borough Latitude  Borough Longitude  \
# 0    Central Toronto         43.701980         -79.398954
# 1    Central Toronto         43.701980         -79.398954
# 2    Central Toronto         43.701980         -79.398954
# 3    Central Toronto         43.701980         -79.398954
# 4    Central Toronto         43.701980         -79.398954
# ..               ...               ...                ...
# 995             York         43.690797         -79.472633
# 996             York         43.690797         -79.472633
# 997             York         43.690797         -79.472633
# 998             York         43.690797         -79.472633
# 999             York         43.690797         -79.472633
#
#                                           Venue  Venue Latitude  \
# 0                                     Balsamico       43.701505
# 1    Mysteriously Yours, Mystery Dinner Theatre       43.701222
# 2                         Jules Cafe Patisserie       43.704138
# 3                                 Little Sister       43.701552
# 4                  Istanbul Cafe & Espresso Bar       43.707891
# ..                                          ...             ...
# 995                        Famiglia Baldassarre       43.670388
# 996                                  Buddha Pie       43.661597
# 997                                Dutch Dreams       43.682182
# 998                 La Bella Managua Restaurant       43.662162
# 999                                   The Abbot       43.703688
#
#      Venue Longitude             Venue Category
# 0         -79.397162         Italian Restaurant
# 1         -79.397251      General Entertainment
# 2         -79.388413               Dessert Shop
# 3         -79.397163      Indonesian Restaurant
# 4         -79.393049                       Café
# ..               ...                        ...
# 995       -79.434999         Italian Restaurant
# 996       -79.479499                Pizza Place
# 997       -79.418893             Ice Cream Shop
# 998       -79.424929  South American Restaurant
# 999       -79.413485                  Gastropub
#
# [1000 rows x 7 columns]

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
toronto_venues['Venue Category'].unique()
# Out:
# There are 181 uniques categories.
# array(['Italian Restaurant', 'General Entertainment', 'Dessert Shop',
#        'Indonesian Restaurant', 'Café', 'Supermarket', 'Park', 'Tea Room',
#        'Plaza', 'Gym', 'Gastropub', 'Deli / Bodega', 'Bakery',
#        'Coffee Shop', 'Yoga Studio', 'Trail', 'Indian Restaurant',
#        'Burger Joint', 'Bagel Shop', 'Tapas Restaurant', 'Flower Shop',
#        'Pizza Place', 'Liquor Store', 'Spa', 'Field', 'Juice Bar',
#        'Grocery Store', 'French Restaurant', 'Garden', 'BBQ Joint',
#        'Sushi Restaurant', 'Fish & Chips Shop', 'Wine Bar',
#        'Mexican Restaurant', 'Historic Site', 'Ice Cream Shop',
#        'Athletics & Sports', 'Farmers Market',
#        'Middle Eastern Restaurant', 'Brewery', 'Sandwich Place',
#        'Sporting Goods Shop', 'Hotel', 'Concert Hall', 'Gourmet Shop',
#        'Bubble Tea Shop', 'Sports Bar', 'Vegetarian / Vegan Restaurant',
#        'Dog Run', 'Dance Studio', 'Shopping Mall', 'Bike Shop',
#        'Other Great Outdoors', 'Breakfast Spot',
#        'South American Restaurant', 'Japanese Restaurant', 'Neighborhood',
#        'Clothing Store', 'Theater', 'American Restaurant',
#        'Mediterranean Restaurant', 'Restaurant', 'Food Truck', 'Bar',
#        'Record Shop', 'Cosmetics Shop', 'Train Station', 'Diner',
#        'Organic Grocery', 'Arts & Crafts Store', 'Monument / Landmark',
#        'Hostel', 'Beer Bar', 'Performing Arts Venue', 'Lake',
#        'Baseball Stadium', 'Pub', 'Cheese Shop', 'Street Art',
#        'Skating Rink', 'Pool', 'Butcher', 'Event Space', 'Cocktail Bar',
#        'Chocolate Shop', 'Comic Shop', 'Egyptian Restaurant',
#        'Asian Restaurant', 'Burrito Place', 'Snack Place', 'Soccer Field',
#        'Beach', 'Latin American Restaurant', 'Ethiopian Restaurant',
#        'Caribbean Restaurant', 'Pakistani Restaurant', 'Boutique',
#        'Vietnamese Restaurant', 'Flea Market', 'Turkish Restaurant',
#        'Hungarian Restaurant', 'Playground', 'Bookstore',
#        'Greek Restaurant', 'Gym / Fitness Center', 'Donut Shop',
#        'Indie Movie Theater', 'Thai Restaurant', 'Farm', 'Pastry Shop',
#        'Warehouse Store', 'Rock Climbing Spot', 'History Museum',
#        'Botanical Garden', 'Cantonese Restaurant', 'Seafood Restaurant',
#        'Golf Course', 'Pool Hall', 'Toy / Game Store',
#        'Eastern European Restaurant', 'Pharmacy', "Women's Store",
#        'Hardware Store', 'Fast Food Restaurant', 'Wings Joint',
#        'Furniture / Home Store', 'Climbing Gym', 'Movie Theater', 'Food',
#        'Taco Place', 'Racetrack', 'Nightclub', 'Chinese Restaurant',
#        'Discount Store', 'Comfort Food Restaurant', 'Hobby Shop',
#        'Paper / Office Supplies Store', 'Falafel Restaurant',
#        'Comedy Club', 'Department Store', 'Hookah Bar',
#        'Portuguese Restaurant', 'Kebab Restaurant', 'Steakhouse',
#        'Bowling Alley', 'Martial Arts Dojo', 'Afghan Restaurant',
#        'Pet Store', 'Camera Store', 'Airport Lounge', 'Bank',
#        'Bridal Shop', 'Ramen Restaurant', 'Jewelry Store',
#        'Recreation Center', 'Creperie', 'Korean Restaurant', 'Poke Place',
#        'Airport', 'Fried Chicken Joint', 'Hockey Arena', 'Fish Market',
#        'Doner Restaurant', 'Outdoor Supply Store',
#        'New American Restaurant', 'Persian Restaurant',
#        'Xinjiang Restaurant', 'Hakka Restaurant', 'Sri Lankan Restaurant',
#        'Bistro', 'Frozen Yogurt Shop', 'Noodle House', 'Cuban Restaurant',
#        'Soup Place', 'Beer Store', 'Scenic Lookout', 'Cupcake Shop',
#        'Tibetan Restaurant', 'Amphitheater', 'Tattoo Parlor', 'Gift Shop'],
#       dtype=object)

# %% [markdown]
# ### Select Business Which are Significantly Affected by COVID-19: Restaurants, Bars, Clubs, Hotels, Gyms

# %%
df=toronto_venues[['Borough','Venue','Venue Category']]
restaurant =df['Venue Category'].str.contains('Restaurant')
bar=df['Venue Category'].str.contains('Bar')
club=df['Venue Category'].str.contains('club')
gym=df['Venue Category'].str.contains('Gym')
hotel=df['Venue Category'].str.contains('Hotel')

# %%
df1=df[restaurant]
df2=df1.append(df[bar])
df3=df2.append(df[gym])
df4=df3.append(df[hotel])
df=df4.append(df[club])

print(df.shape)
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
df.reset_index()
# Out:
# (318, 3)
# (251, 3)
# (286, 3)
# (304, 3)
# (317, 3)
#      index          Borough  \
# 0        0  Central Toronto
# 1        3  Central Toronto
# 2        7  Central Toronto
# 3       21  Central Toronto
# 4       22  Central Toronto
# ..     ...              ...
# 313    545      Mississauga
# 314    551      Mississauga
# 315    557      Mississauga
# 316    607       North York
# 317    479        Etobicoke
#
#                                                  Venue         Venue Category
# 0                                            Balsamico     Italian Restaurant
# 1                                        Little Sister  Indonesian Restaurant
# 2                                             Bar Buca     Italian Restaurant
# 3                                    Grazie Ristorante     Italian Restaurant
# 4                                La Vecchia Ristorante     Italian Restaurant
# ..                                                 ...                    ...
# 313                          Homewood Suites by Hilton                  Hotel
# 314     Best Western Plus Travel Hotel Toronto Airport                  Hotel
# 315  TownePlace Suites Mississauga-Airport Corporat...                  Hotel
# 316                                       Maryam Hotel                  Hotel
# 317                                            The Vue              Nightclub
#
# [318 rows x 4 columns]

# %% [markdown]
# ### Classify Restaurants, Bars and Clubs as 'Dining In', Gyms as 'Working Out', Hotel as 'Checking In'

# %%
df.loc[df['Venue Category'].str.contains('Gym'),'Type']='working Out'
df.loc[df['Venue Category'].str.contains('club'),'Type']='Dining In'
df.loc[df['Venue Category'].str.contains('Bar'),'Type']='Dining In'
df.loc[df['Venue Category'].str.contains('Restaurant'),'Type']='Dining In'
df.loc[df['Venue Category'].str.contains('Restaurant'),'Type']='Checking In'

# %%
df.drop(['Venue Category'], axis=1, inplace= True)
df
# Out:
#              Borough                                              Venue  \
# 0    Central Toronto                                          Balsamico
# 3    Central Toronto                                      Little Sister
# 7    Central Toronto                                           Bar Buca
# 21   Central Toronto                                  Grazie Ristorante
# 22   Central Toronto                              La Vecchia Ristorante
# ..               ...                                                ...
# 545      Mississauga                          Homewood Suites by Hilton
# 551      Mississauga     Best Western Plus Travel Hotel Toronto Airport
# 557      Mississauga  TownePlace Suites Mississauga-Airport Corporat...
# 607       North York                                       Maryam Hotel
# 479        Etobicoke                                            The Vue
#
#             Type
# 0    Checking In
# 3    Checking In
# 7    Checking In
# 21   Checking In
# 22   Checking In
# ..           ...
# 545          NaN
# 551          NaN
# 557          NaN
# 607          NaN
# 479    Dining In
#
# [318 rows x 3 columns]

# %% [markdown]
# ### Analyze and Prepare Boroughs for Cluster Analysis

# %%
business_interupted = pd.get_dummies(df[['Type']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
business_interupted['Borough'] = df['Borough'] 
# move neighborhood column to the first column
fixed_columns = [business_interupted.columns[-1]] + list(business_interupted.columns[:-1])
business_interupted = business_interupted[fixed_columns]
business_interupted.shape
# Out:
# (318, 4)

# %%
toronto_grouped = business_interupted.groupby('Borough').mean().reset_index()
toronto_grouped
# Out:
#             Borough  Checking In  Dining In  working Out
# 0   Central Toronto     0.785714   0.107143     0.071429
# 1  Downtown Toronto     0.681818   0.181818     0.045455
# 2      East Toronto     0.833333   0.083333     0.055556
# 3         East York     0.727273   0.136364     0.090909
# 4         Etobicoke     0.800000   0.066667     0.100000
# 5       Mississauga     0.704545   0.113636     0.045455
# 6        North York     0.846154   0.038462     0.076923
# 7       Scarborough     0.878049   0.024390     0.097561
# 8      West Toronto     0.756757   0.243243     0.000000
# 9              York     0.843750   0.156250     0.000000

# %% [markdown]
# ## Borough Cluster Analysis - Commercial business

# %%
# import k-means from clustering stage
# set number of clusters
kclusters = 3

toronto_grouped_clustering = toronto_grouped.drop('Borough', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([1, 0, 1, 0, 1, 0, 1, 1, 2, 2])

# %%
# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood
toronto_merged = df_group

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
#toronto_merged = toronto_merged.join(borough_venues_sorted.set_index('Borough'), on='Borough)

print(toronto_merged.shape)
toronto_merged # check the last columns!
# Out:
# (10, 4)
#             Borough   Latitude  Longitude  Cluster Labels
# 0   Central Toronto  43.701980 -79.398954               1
# 1  Downtown Toronto  43.654597 -79.383972               0
# 2      East Toronto  43.669436 -79.324654               1
# 3         East York  43.700303 -79.335851               0
# 4         Etobicoke  43.660043 -79.542074               1
# 5       Mississauga  43.636966 -79.615819               0
# 6        North York  43.750727 -79.429338               1
# 7       Scarborough  43.766229 -79.249085               1
# 8      West Toronto  43.652653 -79.449290               2
# 9              York  43.690797 -79.472633               2

# %% [markdown]
# ## Visualize the Final Clusters

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Borough'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=10).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Analysis on Residential Property due to COVID-19

# %% [markdown]
# ## Collect Residential Information using Foursquare API

# %%
def getNearbyResidence(names, latitudes, longitudes, radius=50000):
    LIMIT = 100 # limit of number of venues returned by Foursquare API
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            '4e67e38e036454776db1fb3a')
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_residence = getNearbyResidence(names=df_group['Borough'],
                                   latitudes=df_group['Latitude'],
                                   longitudes=df_group['Longitude']
                                  )
toronto_residence
# Out:
# Central Toronto
# Downtown Toronto
# East Toronto
# East York
# Etobicoke
# Mississauga
# North York
# Scarborough
# West Toronto
# York
#              Borough  Borough Latitude  Borough Longitude  \
# 0    Central Toronto         43.701980         -79.398954
# 1    Central Toronto         43.701980         -79.398954
# 2    Central Toronto         43.701980         -79.398954
# 3    Central Toronto         43.701980         -79.398954
# 4    Central Toronto         43.701980         -79.398954
# ..               ...               ...                ...
# 995             York         43.690797         -79.472633
# 996             York         43.690797         -79.472633
# 997             York         43.690797         -79.472633
# 998             York         43.690797         -79.472633
# 999             York         43.690797         -79.472633
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0    One King West Hotel & Residence       43.649139       -79.377876
# 1                   The Ritz-Carlton       43.645330       -79.387089
# 2         Four Seasons Hotel Toronto       43.671796       -79.389457
# 3                    Bayview Village       43.768527       -79.385494
# 4                 Windsor Arms Hotel       43.668781       -79.390850
# ..                               ...             ...              ...
# 995   Applewood Landmark Condominium       43.618677       -79.600328
# 996                    La Viva Towns       43.781140       -79.584920
# 997               CAPREIT Apartments       43.611039       -79.601413
# 998               165 Barrington Ave       43.694220       -79.302417
# 999                   508 Dawes Road       43.703737       -79.297905
#
#                                Venue Category
# 0                                       Hotel
# 1                                       Hotel
# 2                                       Hotel
# 3                               Shopping Mall
# 4                                       Hotel
# ..                                        ...
# 995  Residential Building (Apartment / Condo)
# 996  Residential Building (Apartment / Condo)
# 997  Residential Building (Apartment / Condo)
# 998  Residential Building (Apartment / Condo)
# 999  Residential Building (Apartment / Condo)
#
# [1000 rows x 7 columns]

# %%
toronto_residence['Venue Category'].unique()
# Out:
# array(['Hotel', 'Shopping Mall', 'Hospital', 'College Residence Hall',
#        'Residential Building (Apartment / Condo)', 'Other Great Outdoors',
#        'Housing Development', 'Building', 'Breakfast Spot',
#        'College Quad', 'Office'], dtype=object)

# %% [markdown]
# ### Test Assisted Living Venue Category - No Sufficient Information from Foursquare

# %%
# Interesting findings that Assisted Living was removed from the Foursquare after I attempted to refresht the databased 2 days after I finished analysis, also limited info. from Foursquare does make me doubt about the data credibility
df=toronto_residence
df_test=df[df['Venue Category']=='Assisted Living']
df_test
# Out:
# Empty DataFrame
# Columns: [Borough, Borough Latitude, Borough Longitude, Venue, Venue Latitude, Venue Longitude, Venue Category]
# Index: []

# %% [markdown]
# ### Select Residential Building (Apartment / Condo)

# %%
df=toronto_residence
resi=df['Venue Category']=='Residential Building (Apartment / Condo)'
df=df[resi]
df_condo=df[['Borough','Venue','Venue Category']]
df_condo
# Out:
#              Borough                                   Venue  \
# 9    Central Toronto  Summerhill Properties - The Summerhill
# 13   Central Toronto                          Madison Condos
# 14   Central Toronto                          The Park Villa
# 15   Central Toronto                      118 Balliol Street
# 16   Central Toronto                        Minto Roehampton
# ..               ...                                     ...
# 995             York          Applewood Landmark Condominium
# 996             York                           La Viva Towns
# 997             York                      CAPREIT Apartments
# 998             York                      165 Barrington Ave
# 999             York                          508 Dawes Road
#
#                                Venue Category
# 9    Residential Building (Apartment / Condo)
# 13   Residential Building (Apartment / Condo)
# 14   Residential Building (Apartment / Condo)
# 15   Residential Building (Apartment / Condo)
# 16   Residential Building (Apartment / Condo)
# ..                                        ...
# 995  Residential Building (Apartment / Condo)
# 996  Residential Building (Apartment / Condo)
# 997  Residential Building (Apartment / Condo)
# 998  Residential Building (Apartment / Condo)
# 999  Residential Building (Apartment / Condo)
#
# [860 rows x 3 columns]

# %% [markdown]
# ## Import Nursing and Residential Care Facilities Data from Statisticas Canada

# %%
# Read the downloaded  file by its local path , and assign it to variable "df_rf"
df_rf = pd.read_csv(r"C:\Users\e78202\Desktop\projects\Coursera_Capstone\odhf_v1.csv", header= 0,engine ='python')
df_rf.head()
# Out:
#    index                             facility_name   source_facility_type  \
# 0      1    advanced facial & nasal surgery centre  active acute hospital
# 1      2         agecare — beverly centre glenmore         long term care
# 2      3   agecare — beverly centre lake midnapore         long term care
# 3      4  agecare — sagewood seniors community inc         long term care
# 4      5                           agecare — seton         long term care
#
#                         odhf_facility_type  \
# 0                                Hospitals
# 1  Nursing and residential care facilities
# 2  Nursing and residential care facilities
# 3  Nursing and residential care facilities
# 4  Nursing and residential care facilities
#
#                                     provider unit street_no street_name  \
# 0  Canadian Institute for Health Information  NaN       NaN         NaN
# 1  Canadian Institute for Health Information  NaN       NaN         NaN
# 2  Canadian Institute for Health Information  NaN       NaN         NaN
# 3  Canadian Institute for Health Information  NaN       NaN         NaN
# 4  Canadian Institute for Health Information  NaN       NaN         NaN
#
#   postal_code        city province source_format_str_address     CSDname  \
# 0      T5M4G5    edmonton       ab                       NaN    Edmonton
# 1      T2V4S1     calgary       ab                       NaN     Calgary
# 2      T2X3S3     calgary       ab                       NaN     Calgary
# 3      T1P0E2  strathmore       ab                       NaN  Strathmore
# 4      T3M2M3     calgary       ab                       NaN     Calgary
#
#    CSDuid  Pruid  latitude  longitude
# 0     NaN     48       NaN        NaN
# 1     NaN     48       NaN        NaN
# 2     NaN     48       NaN        NaN
# 3     NaN     48       NaN        NaN
# 4     NaN     48       NaN        NaN

# %% [markdown]
# ### Select Nursing and Residental Care Faciliites in Toronto

# %%
toronto=df_rf['city']=='toronto'
facility=df_rf['odhf_facility_type']=='Nursing and residential care facilities'
df_temp=df_rf[toronto&facility]
df_temp
# Out:
#       index                                      facility_name  \
# 2401   2402                              147 elder street inc.
# 2405   2406                 a better way retirement home corp.
# 2406   2407                      a-way express courier service
# 2421   2422        accommodation, information and support inc.
# 2422   2423  across boundaries: an ethnocultural mental hea...
# ...     ...                                                ...
# 6091   6092                       woodgreen community services
# 6104   6105                                 working for change
# 6110   6111                yee hong centre - scarborough finch
# 6111   6112             yee hong centre - scarborough mcnicoll
# 6129   6130                                       ywca toronto
#
#                           source_facility_type  \
# 2401                           retirement home
# 2405                           retirement home
# 2406  mental health and addiction organization
# 2421  mental health and addiction organization
# 2422  mental health and addiction organization
# ...                                        ...
# 6091  mental health and addiction organization
# 6104  mental health and addiction organization
# 6110                       long-term care home
# 6111                       long-term care home
# 6129  mental health and addiction organization
#
#                            odhf_facility_type             provider unit  \
# 2401  Nursing and residential care facilities  Province of Ontario  NaN
# 2405  Nursing and residential care facilities  Province of Ontario  NaN
# 2406  Nursing and residential care facilities  Province of Ontario  NaN
# 2421  Nursing and residential care facilities  Province of Ontario  NaN
# 2422  Nursing and residential care facilities  Province of Ontario  NaN
# ...                                       ...                  ...  ...
# 6091  Nursing and residential care facilities  Province of Ontario  NaN
# 6104  Nursing and residential care facilities  Province of Ontario  NaN
# 6110  Nursing and residential care facilities  Province of Ontario  NaN
# 6111  Nursing and residential care facilities  Province of Ontario  NaN
# 6129  Nursing and residential care facilities  Province of Ontario  NaN
#
#      street_no          street_name postal_code     city province  \
# 2401       147         elder street      M3H5G9  toronto       on
# 2405        22     purpledusk trail      M1E4C7  toronto       on
# 2406      2168      danforth avenue      M4C1K3  toronto       on
# 2421       720       spadina avenue      M5S2T9  toronto       on
# 2422         1  york gate boulevard      M3N3A1  toronto       on
# ...        ...                  ...         ...      ...      ...
# 6091      1070       queen street e      M4M3M4  toronto       on
# 6104       250       college street      M5T1R8  toronto       on
# 6110        60     scottfield drive      M1S5T7  toronto       on
# 6111      2311      mcnicoll avenue      M1V5L3  toronto       on
# 6129       150     elizabeth street      M5G0A9  toronto       on
#
#      source_format_str_address  CSDname     CSDuid  Pruid   latitude  \
# 2401                       NaN  Toronto  3520005.0     35  43.762894
# 2405                       NaN  Toronto  3520005.0     35  43.783661
# 2406                       NaN  Toronto  3520005.0     35  43.686643
# 2421                       NaN  Toronto  3520005.0     35  43.665394
# 2422                       NaN  Toronto  3520005.0     35  43.758995
# ...                        ...      ...        ...    ...        ...
# 6091                       NaN  Toronto  3520005.0     35  43.661902
# 6104                       NaN  Toronto  3520005.0     35  43.658413
# 6110                       NaN  Toronto  3520005.0     35  43.808717
# 6111                       NaN  Toronto  3520005.0     35  43.814232
# 6129                       NaN  Toronto  3520005.0     35  43.656539
#
#       longitude
# 2401 -79.454109
# 2405 -79.207601
# 2406 -79.310667
# 2421 -79.403480
# 2422 -79.518807
# ...         ...
# 6091 -79.337052
# 6104 -79.398971
# 6110 -79.254665
# 6111 -79.290217
# 6129 -79.386008
#
# [278 rows x 17 columns]

# %% [markdown]
# ### Data Preparation for Merging with Toronto Geospatical Data

# %%
df=df_temp
array=['retirement home','long term care','long-term care home',]
df=df.loc[df['source_facility_type'].isin(array)]
df_care =df[['facility_name','odhf_facility_type','postal_code']]
df_care.rename(columns = {'facility_name':'Venue','odhf_facility_type':'Venue Category'},inplace=True)
df_care['PostalCode']=df.postal_code.str.slice(0,3)
df_care
# Out:
# C:\Users\e78202\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\e78202\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                        Venue  \
# 2401                   147 elder street inc.
# 2405      a better way retirement home corp.
# 2431                         adeline's lodge
# 2433  advent forestview retirement residence
# 2445       alexis lodge retirement residence
# ...                                      ...
# 6036     weston gardens retirement residence
# 6037           weston terrace care community
# 6039                                westside
# 6110     yee hong centre - scarborough finch
# 6111  yee hong centre - scarborough mcnicoll
#
#                                Venue Category postal_code PostalCode
# 2401  Nursing and residential care facilities      M3H5G9        M3H
# 2405  Nursing and residential care facilities      M1E4C7        M1E
# 2431  Nursing and residential care facilities      M8W1C1        M8W
# 2433  Nursing and residential care facilities      M2R0A8        M2R
# 2445  Nursing and residential care facilities      M1P2W1        M1P
# ...                                       ...         ...        ...
# 6036  Nursing and residential care facilities      M6L3C1        M6L
# 6037  Nursing and residential care facilities      M9N3V4        M9N
# 6039  Nursing and residential care facilities      M9V4J7        M9V
# 6110  Nursing and residential care facilities      M1S5T7        M1S
# 6111  Nursing and residential care facilities      M1V5L3        M1V
#
# [177 rows x 4 columns]

# %%
df_tot
# Out:
#     PostalCode      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# ..         ...          ...
# 98         M9N         York
# 99         M9P    Etobicoke
# 100        M9R    Etobicoke
# 101        M9V    Etobicoke
# 102        M9W    Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                      Malvern , Rouge  43.806686 -79.194353
# 1             Rouge Hill , Port Union , Highland Creek  43.784535 -79.160497
# 2                  Guildwood , Morningside , West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village , St. Phillips , Martin Grov...  43.688905 -79.554724
# 101  South Steeles , Silverstone , Humbergate , Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
df_senior=pd.merge(df_care,df_tot,left_on='PostalCode',right_on='PostalCode')
df_senior.drop(['postal_code','Neighborhood','Latitude', 'Longitude','PostalCode'],axis=1,inplace=True)
df_senior
# Out:
#                                      Venue  \
# 0                    147 elder street inc.
# 1    kensington place retirement residence
# 2            l'chaim retirement homes inc.
# 3       a better way retirement home corp.
# 4                     ehatare nursing home
# ..                                     ...
# 171                wellesley central place
# 172                         the teddington
# 173          the village of humber heights
# 174                            the wexford
# 175       villa colombo homes for the aged
#
#                               Venue Category           Borough
# 0    Nursing and residential care facilities        North York
# 1    Nursing and residential care facilities        North York
# 2    Nursing and residential care facilities        North York
# 3    Nursing and residential care facilities       Scarborough
# 4    Nursing and residential care facilities       Scarborough
# ..                                       ...               ...
# 171  Nursing and residential care facilities  Downtown Toronto
# 172  Nursing and residential care facilities   Central Toronto
# 173  Nursing and residential care facilities         Etobicoke
# 174  Nursing and residential care facilities       Scarborough
# 175  Nursing and residential care facilities        North York
#
# [176 rows x 3 columns]

# %%
df=pd.concat([df_condo,df_senior],axis=0,join='outer',ignore_index=False)
df
# Out:
#               Borough                                   Venue  \
# 9     Central Toronto  Summerhill Properties - The Summerhill
# 13    Central Toronto                          Madison Condos
# 14    Central Toronto                          The Park Villa
# 15    Central Toronto                      118 Balliol Street
# 16    Central Toronto                        Minto Roehampton
# ..                ...                                     ...
# 171  Downtown Toronto                 wellesley central place
# 172   Central Toronto                          the teddington
# 173         Etobicoke           the village of humber heights
# 174       Scarborough                             the wexford
# 175        North York        villa colombo homes for the aged
#
#                                Venue Category
# 9    Residential Building (Apartment / Condo)
# 13   Residential Building (Apartment / Condo)
# 14   Residential Building (Apartment / Condo)
# 15   Residential Building (Apartment / Condo)
# 16   Residential Building (Apartment / Condo)
# ..                                        ...
# 171   Nursing and residential care facilities
# 172   Nursing and residential care facilities
# 173   Nursing and residential care facilities
# 174   Nursing and residential care facilities
# 175   Nursing and residential care facilities
#
# [1036 rows x 3 columns]

# %% [markdown]
# ### Analyze And Prepare Residentical Information For Cluster Analysis

# %%
residence = pd.get_dummies(df[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
residence['Borough'] = df['Borough'] 
# move neighborhood column to the first column
fixed_columns = [residence.columns[-1]] + list(residence.columns[:-1])
residence = residence[fixed_columns]
print(residence.shape)

residence_grouped = residence.groupby('Borough').mean().reset_index()
residence_grouped
# Out:
# (1036, 3)
#             Borough  Nursing and residential care facilities  \
# 0   Central Toronto                                 0.179245
# 1  Downtown Toronto                                 0.173077
# 2      East Toronto                                 0.075269
# 3         East York                                 0.064516
# 4         Etobicoke                                 0.218182
# 5       Mississauga                                 0.000000
# 6        North York                                 0.312000
# 7       Scarborough                                 0.322835
# 8      West Toronto                                 0.158416
# 9              York                                 0.064516
#
#    Residential Building (Apartment / Condo)
# 0                                  0.820755
# 1                                  0.826923
# 2                                  0.924731
# 3                                  0.935484
# 4                                  0.781818
# 5                                  1.000000
# 6                                  0.688000
# 7                                  0.677165
# 8                                  0.841584
# 9                                  0.935484

# %% [markdown]
# ## Borough Cluster Analysis - Residence

# %%
# import k-means from clustering stage
# set number of clusters
kclusters = 3

residence_grouped_clustering = residence_grouped.drop('Borough', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(residence_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([1, 1, 0, 0, 1, 0, 2, 2, 1, 0])

# %%
# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood
residence_merged = df_group

# add clustering labels
residence_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood

print(residence_merged.shape)
residence_merged # check the last columns!
# Out:
# (10, 4)
#             Borough   Latitude  Longitude  Cluster Labels
# 0   Central Toronto  43.701980 -79.398954               1
# 1  Downtown Toronto  43.654597 -79.383972               1
# 2      East Toronto  43.669436 -79.324654               0
# 3         East York  43.700303 -79.335851               0
# 4         Etobicoke  43.660043 -79.542074               1
# 5       Mississauga  43.636966 -79.615819               0
# 6        North York  43.750727 -79.429338               2
# 7       Scarborough  43.766229 -79.249085               2
# 8      West Toronto  43.652653 -79.449290               1
# 9              York  43.690797 -79.472633               0

# %% [markdown]
# ### Visualize the Final Clusters- Residence

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(residence_merged['Latitude'], residence_merged['Longitude'], residence_merged['Borough'], residence_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=10).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
